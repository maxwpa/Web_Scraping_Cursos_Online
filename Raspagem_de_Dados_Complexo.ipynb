# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# url = 'https://carranzacursos.com.br/todos-os-cursos/'
# resposta = requests.get(url)
# conteudo = resposta.content
# site = BeautifulSoup(conteudo, 'html.parser')
# informa = site.find('div', attrs={'class': 'product-details-wrap'})
# link = informa.find('a')['href']
# resposta_curso = requests.get(link)
# conteudo_curso = resposta_curso.content
# pagina = BeautifulSoup(conteudo_curso, 'html.parser')
# filtro = pagina.find('span', attrs={'class': 'elementor-icon-list-text'}).text
# if filtro == 'Resumo do edital':
#     Concurso = pagina.find('h3', attrs={'class': 'elementor-image-box-title'}).text
#     Status = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[1].text
#     Status = Status.replace('Status:', '').strip()
#     Periodo_de_Inscrição = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[2].text
#     Periodo_de_Inscrição = Periodo_de_Inscrição.replace('Período de Inscrições:', '').strip()
#     Remuneração_Inicial = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[3].text
#     Remuneração_Inicial = Remuneração_Inicial.replace('Remuneração inicial:', '').strip()
#     Cargos = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[4].text
#     Cargos = Cargos.replace('Cargos:', '').strip()
#     Escolaridade = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[5].text
#     Escolaridade = Escolaridade.replace('Escolaridade:', '').strip()
#     Taxa_de_Inscrição = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[6].text
#     Taxa_de_Inscrição = Taxa_de_Inscrição.replace('Taxa de inscrição:', '').strip()
#     Data_da_Prova = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[7].text
#     Data_da_Prova = Data_da_Prova.replace('Data da prova:', '').strip()
#     Número_de_Vagas = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[8].text
#     Número_de_Vagas = Número_de_Vagas.replace('Número de vagas:', '').strip()
#     Banca_Organizadora = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[9].text
#     Banca_Organizadora = Banca_Organizadora.replace('Banca organizadora:', '').strip()
#     Lotação = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[10].text
#     Lotação = Lotação.replace('Lotação:', '').strip()
#     Cursos = pagina.find_all('a', attrs={'class': 'elementor-toggle-title'})
#     Cursos = [curso.text for curso in Cursos[:5]]
#     Preço_Original = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})[4].text
#     Preço_Original = Preço_Original.replace('R$', '')
#     Preço_Original = float(Preço_Original.replace(',', '.'))
#     Oferta_a_Vista = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})[8].text
#     Oferta_a_Vista = Oferta_á_Vista.replace('R$', '')
#     Oferta_a_Vista = float(Oferta_a_Vista.replace(',', '.'))
#     Parcelamento = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})
#     Parcelamento = [parcela.text for parcela in Parcelamento[6:8]]
#     Parcelamento = ' '.join(Parcelamento)
#     Valor_da_Parcela = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})[5].text
#     Valor_da_Parcela = Valor_da_Parcela.replace('R$', '')
#     Valor_da_Parcela = float(Valor_da_Parcela.replace(',', '.'))
#     Abrangência = pagina.find('b').text

# %%
print(Valor_da_Parcela)
# Out:
# 32.83

# %%
print(link)
# Out:
# https://carranzacursos.com.br/product/ifbaiano/

# %%
def extrair_informacoes_curso(link):
    resposta_curso = requests.get(link)
    conteudo_curso = resposta_curso.content
    pagina = BeautifulSoup(conteudo_curso, 'html.parser')

    filtro_element = pagina.find('span', attrs={'class': 'elementor-icon-list-text'})
    if filtro_element:
        filtro = filtro_element.text
    else:
        filtro = None

    if filtro == 'Resumo do edital':
        Concurso = pagina.find('h3', attrs={'class': 'elementor-image-box-title'}).text

        Status = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[1].text
        Status = Status.replace('Status:', '').strip()
        
        Periodo_de_Inscrição = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[2].text
        Periodo_de_Inscrição = Periodo_de_Inscrição.replace('Período de Inscrições:', '').strip()
        
        Remuneração_Inicial = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[3].text
        Remuneração_Inicial = Remuneração_Inicial.replace('Remuneração inicial:', '').strip()
        
        Cargos = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[4].text
        Cargos = Cargos.replace('Cargos:', '').strip()
        
        Escolaridade = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[5].text
        Escolaridade = Escolaridade.replace('Escolaridade:', '').strip()
        
        Taxa_de_Inscrição = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[6].text
        Taxa_de_Inscrição = Taxa_de_Inscrição.replace('Taxa de inscrição:', '').strip()
        
        Data_da_Prova = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[7].text
        Data_da_Prova = Data_da_Prova.replace('Data da prova:', '').strip()
        
        Número_de_Vagas = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[8].text
        Número_de_Vagas = Número_de_Vagas.replace('Número de vagas:', '').strip()
        
        Banca_Organizadora = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[9].text
        Banca_Organizadora = Banca_Organizadora.replace('Banca organizadora:', '').strip()
        
        Lotação = pagina.find_all('span', attrs={'class': 'elementor-icon-list-text'})[10].text
        Lotação = Lotação.replace('Lotação:', '').strip()
        
        Cursos = pagina.find_all('a', attrs={'class': 'elementor-toggle-title'})
        Cursos = [curso.text for curso in Cursos[:5]]
        
        Preço_Original = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})[4].text
        Preço_Original = Preço_Original.replace('R$', '')
        if Preço_Original.replace('.', '', 1).replace(',', '', 1).isdigit():
            Preço_Original = float(Preço_Original.replace(',', '.'))
        else:
            Preço_Original = None
    
        elementos_oferta_vista = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})
        if len(elementos_oferta_vista) > 8:
            Oferta_a_Vista = elementos_oferta_vista[8].text.replace('R$', '')
            if Oferta_a_Vista.replace('.', '', 1).replace(',', '', 1).isdigit():
                Oferta_a_Vista = float(Oferta_a_Vista.replace(',', '.'))
            else:
                Oferta_a_Vista = None  # Ou defina um valor padrão que faça sentido no seu contexto
        else:
            Oferta_a_Vista = None
        
        Parcelamento = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})
        Parcelamento = [parcela.text for parcela in Parcelamento[6:8]]
        Parcelamento = ' '.join(Parcelamento)
        
    
        elementos_valor_parcela = pagina.find_all('h2', attrs={'class': 'elementor-heading-title elementor-size-default'})
        if len(elementos_valor_parcela) > 5:
            Valor_da_Parcela = elementos_valor_parcela[5].text.replace('R$', '')

            if Valor_da_Parcela.replace('.', '', 1).replace(',', '', 1).isdigit():
                Valor_da_Parcela = float(Valor_da_Parcela.replace(',', '.'))
            else:
                Valor_da_Parcela = None  
        else:
            Valor_da_Parcela = None
    
        Abrangência = pagina.find('b').text
        
        return {
            'Concurso': Concurso,
            'Status': Status,
            'Periodo_de_Inscrição': Periodo_de_Inscrição,
            'Remuneração_Inicial': Remuneração_Inicial,
            'Cargos': Cargos,
            'Escolaridade': Escolaridade,
            'Taxa_de_Inscrição': Taxa_de_Inscrição,
            'Data_da_Prova': Data_da_Prova,
            'Número_de_Vagas': Número_de_Vagas,
            'Banca_Organizadora': Banca_Organizadora,
            'Lotação': Lotação,
            'Cursos': Cursos,
            'Preço_Original': Preço_Original,
            'Oferta_a_Vista': Oferta_a_Vista,
            'Parcelamento': Parcelamento,
            'Valor_da_Parcela': Valor_da_Parcela,
            'Abrangência': Abrangência}

dados_cursos = []

for page_number in range(1, 11):
    url = f'https://carranzacursos.com.br/todos-os-cursos/page/{page_number}/'
    resposta = requests.get(url)
    conteudo = resposta.content
    site = BeautifulSoup(conteudo, 'html.parser')

    links_cursos = [curso.find('a')['href'] for curso in site.find_all('div', attrs={'class': 'product-details-wrap'})]

    for link_curso in links_cursos:
        informacoes_curso = extrair_informacoes_curso(link_curso)
        if informacoes_curso is not None:
            dados_cursos.append(informacoes_curso)

df = pd.DataFrame(dados_cursos)
df = df.replace({None: pd.NA})
display(df)
# Out:
#                                              Concurso            Status  \
# 0   Universidade Federal de Mato Grosso do Sul (UFMS)  Edital publicado
# 1   Universidade Federal de Mato Grosso do Sul (UFMS)  Edital publicado
# 2   Universidade Federal do Agreste de Pernambuco ...  Edital publicado
# 3                   Concurso Nacional Unificado (CNU)    Banca definida
# 4     Instituto Federal do Rio Grande do Norte (IFRN)  Edital publicado
# ..                                                ...               ...
# 95    Instituto Federal do Rio Grande do Norte (IFRN)  Edital publicado
# 96              Universidade Federal de Sergipe (UFS)  Edital publicado
# 97  Instituto Federal de Educação, Ciência e Tecno...  Edital publicado
# 98  Instituto Federal de Educação, Ciência e Tecno...  Edital publicado
# 99      Prefeitura de Caucaia - Agente Administrativo  Edital publicado
#
#                           Periodo_de_Inscrição  \
# 0                      02.01.2024 A 09.02.2024
# 1                      02.01.2024 A 09.02.2024
# 2                      26/12/2023 a 08/02/2024
# 3
# 4   de 14 de novembro a 07 de dezembro de 2023
# ..                                         ...
# 95  de 14 de novembro a 07 de dezembro de 2023
# 96   de 27 de outubro a 26 de novembro de 2023
# 97                          27/11 a 27/12/2023
# 98                          27/11 a 27/12/2023
# 99                               23.10 a 30.11
#
#                  Remuneração_Inicial                             Cargos  \
# 0                                     Técnico em Assunstos Educacionais
# 1                                     Técnico em Assunstos Educacionais
# 2          R$ 2.667,19 a R$ 4.556,92                           diversos
# 3           Inicial de até R$ 22 mil   Diversos (Blocos 01, 04, 05, 08)
# 4       de R$ 2.667,19 a R$ 4.556,92                           Diversos
# ..                               ...                                ...
# 95      de R$ 2.667,19 a R$ 4.556,92                           Diversos
# 96        de R$2.120,13 a R$4.556,92                           Diversos
# 97         R$ 2.120,13 a R$ 5.362,69                           Diversos
# 98         R$ 2.120,13 a R$ 5.362,69                           Diversos
# 99  entre R$ 1.320,00 e R$ 14.744,12                           Diversos
#
#                         Escolaridade        Taxa_de_Inscrição  \
# 0                     Nível Superior                R$ 100,00
# 1                     Nível Superior                R$ 100,00
# 2   níveis médio, técnico e superior      R$ 80,00 a R$100,00
# 3            Níveis médio e superior
# 4   Níveis médio, técnico e superior  de R$ 55,00 a R$ 115,00
# ..                               ...                      ...
# 95  Níveis médio, técnico e superior  de R$ 55,00 a R$ 115,00
# 96  Níveis médio, técnico e superior  de R$ 70,00 a R$ 150,00
# 97         médio, técnico e superior
# 98         médio, técnico e superior
# 99           Níveis superior e médio
#
#             Data_da_Prova Número_de_Vagas   Banca_Organizadora  \
# 0                   17.03        25 Vagas                FAPEC
# 1                   17.03        25 Vagas                FAPEC
# 2              24/03/2024        55 vagas     Instituto Access
# 3                             6.590 vagas  Fundação Cesgranrio
# 4   21 de janeiro de 2024        51 vagas              FUNCERN
# ..                    ...             ...                  ...
# 95  21 de janeiro de 2024        51 vagas              FUNCERN
# 96  28 de janeiro de 2024        90 vagas       Instituto AOCP
# 97             18/02/2024         96 + CR               IDECAN
# 98             18/02/2024         96 + CR               IDECAN
# 99                  28.01           1.903     Fundação CETREDE
#
#                           Lotação  \
# 0              Mato Grosso do Sul
# 1              Mato Grosso do Sul
# 2                 Pernambuco – PE
# 3                        nacional
# 4   Estado do Rio Grande do Norte
# ..                            ...
# 95  Estado do Rio Grande do Norte
# 96              Estado de Sergipe
# 97
# 98
# 99                     Caucaia-CE
#
#                                                Cursos  Preço_Original  \
# 0   [LÍNGUA PORTUGUESA , LEGISLAÇÃO , RACIOCÍNIO L...          497.00
# 1   [LÍNGUA PORTUGUESA , LEGISLAÇÃO , RACIOCÍNIO L...          597.00
# 2   [Língua Portuguesa , Matemática e Raciocínio L...          597.00
# 3   [Língua Portuguesa (pré-edital com atualização...             NaN
# 4   [Legislação , Língua Portuguesa , Conhecimento...           38.39
# ..                                                ...             ...
# 95  [Legislação , Língua Portuguesa , Conhecimento...           33.74
# 96  [Língua Portuguesa , Raciocínio Lógico, Inform...           31.99
# 97  [LÍNGUA PORTUGUESA, RACIOCÍNIO LÓGICO, NOÇÕES ...           37.23
# 98  [LÍNGUA PORTUGUESA, RACIOCÍNIO LÓGICO, NOÇÕES ...           37.22
# 99  [LÍNGUA PORTUGUESA , MATEMÁTICA , ATUALIDADES ...          597.00
#
#     Oferta_a_Vista                                       Parcelamento  \
# 0              NaN                                       12x R$273,35
# 1              NaN                                       12x R$394,02
# 2           394.08                                      12x sem juros
# 3              NaN
# 4           597.00                           R$394,02 Oferta especial
# ..             ...                                                ...
# 95          597.00                           R$346,26 Oferta especial
# 96          597.00                           R$328,35 Oferta especial
# 97             NaN  R$382,08 Assistente em administração ou Assist...
# 98             NaN                             R$382,08 Administrador
# 99             NaN                                       12x R$298,50
#
#     Valor_da_Parcela                                        Abrangência
# 0              26.63                        Cargo: Conhecimentos gerais
# 1              38.39            Cargo: Técnico em Assuntos Educacionais
# 2              32.84                 Cargo: Assistente em administração
# 3                NaN  maior concurso para áreas administrativas da h...
# 4                NaN                                    Cargo: Pedagogo
# ..               ...                                                ...
# 95               NaN  Cargos: Assistente em Administração ou Assiste...
# 96               NaN  cronograma de Estudos, material teórico abrang...
# 97               NaN  Cargos: Assistente em administração/ Assistent...
# 98               NaN                              Cargo: Administrador
# 99             29.08  cronograma de Estudos, material teórico abrang...
#
# [100 rows x 17 columns]
